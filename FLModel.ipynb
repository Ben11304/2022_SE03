# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import LabelEncoder
import numpy as np
from data_work import data_split
from data_work import processed
from data_work import analyse_dataset
from data_work import set_data
from sklearn.model_selection import train_test_split
import pandas as pd
data=pd.read_csv("C:\\NCKH\\FLMODEL\\datanonid.csv",index_col=None)

# %%
id=[16,17,21,22,23,24]
col=data.columns
for idx in id:
    data=data.drop(col[idx],axis=1)
data=data.drop(columns='attack')
data=data.drop(columns='category')
data = processed(data,"subcategory ")

# %%
traindata,test_data=train_test_split(data,test_size=0.2,random_state=42,stratify=data['subcategory '])
data = traindata.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)
client_data,server_data=train_test_split(traindata,test_size=0.001,random_state=42)
client_data = client_data.reset_index(drop=True)
server_data = server_data.reset_index(drop=True)

# %%
test_data.shape
# Out:
# (843, 27)

# %%
testdata_list=set_data([test_data])[0]

#chia data thành list gồm 2 phàn tử [0] là X, [1] là y
# Out:
# len X 1406, len y 1406

# %% [markdown]
# # iid dataset setup

# %%
from model import Net

# %% [markdown]
# ##Create model function

# %%
import torch
import torch.nn as nn

# %%
trainloaders,testloaders=data_split(client_data,"subcategory ",8,0.1,IID=1)
# Out:
# prepairing IID dataset
# len of client data :5614, len of each subdata : 701
# client number 1 : train(631), val(70)
# client number 2 : train(631), val(70)
# client number 3 : train(631), val(70)
# client number 4 : train(631), val(70)
# client number 5 : train(631), val(70)
# client number 6 : train(631), val(70)
# client number 7 : train(631), val(70)
# client number 8 : train(631), val(70)

# %%
names=["subcategory "]
a=analyse_dataset(trainloaders[7],names)
print(a)
# Out:
# thống kê nhãn subcategory :
# 6 73
# 7 98
# 5 89
# 3 89
# 1 101
# 2 79
# 4 87
# 0 15
# [6, 7, 5, 3, 1, 2, 4, 0]

# %%
def semantic_backdoor(data,feature):
    threshold = data[feature].max()
    data.loc[data[feature] >= (threshold*0.75),"subcategory "]= 0
    return data

# %% [markdown]
# ##Client

# %%
class client():
    def __init__(self,cid,net):
        self.cid=cid 
        self.model=net
        self.trainset=trainloaders[cid]
        self.client_label=analyse_dataset(trainloaders[cid],["subcategory "])
        self.discrete_columns=list(trainloaders[cid].columns)

    def fit(self ):
        # Read values from config
        self.model.fit(self.trainset, self.discrete_columns)
        return "ok"
    
    def Gen_fake_data(self,n_samples):
        synthetic_data = self.model.sample(n_samples)
        return synthetic_data

# %%
config = {
    "server_round": 3,
    "local_epochs": 5
    
}

# %%
def client_fn(cid: str,config): 
    server_round = config["server_round"]
    local_epochs = config["local_epochs"]
    net = Net(0.00)
    print(cid)
    return client(cid, net)

# %%
input_shape=data.shape[1]
data.shape
# Out:
# (5620, 27)

# %%
def data_backdoor(data,feature): 
    threshold = data[feature].max()
    print(threshold)
    filtered_df = data[data[feature] >= threshold*0.75]
    print(filtered_df[feature])
    X_backdoor,Y_backdoor=filtered_df.iloc[:, 1:].values,filtered_df.iloc[:, 0].values
    X_backdoor=torch.tensor((X_backdoor))
    Y_backdoor=Y_backdoor.squeeze().tolist()
    Y_backdoor=torch.tensor(Y_backdoor)
    return X_backdoor,Y_backdoor
X_backdoor,Y_backdoor=data_backdoor(data,'dur')
# Out:
# 2917
# 3       2358
# 6       2548
# 7       2439
# 9       2758
# 11      2735
#         ...
# 5608    2459
# 5611    2377
# 5613    2744
# 5618    2478
# 5619    2355
# Name: dur, Length: 1822, dtype: int64

# %% [markdown]
# ##Server

# %%
import random
class server():
    def __init__(self):
        self.server_model=Net(0.00)
        self.trainset=server_data
        self.testset=testdata_list
        self.clients=[]
        n_clients=8
        config = {
            "server_round": round,
            "local_epochs": 5
        }
        for i in range(n_clients):
            client=client_fn(i,config)
            self.clients.append(client)

    def average_parameters(self, parameter_list):
        # Tính trung bình của các tensor trong danh sách
        avg_params = []
        for params in zip(*parameter_list):
            avg_param = torch.mean(torch.stack(params), dim=0)
            avg_params.append(avg_param)
        
        return avg_params



    #def fit_round():
    def simulation(self,rounds):
        
        for round in range(rounds):
            parameter=[]
            for i in range(len(self.clients)):
                #kết hợp data sever và xáo trộn
                data1 = pd.concat([self.clients[i].trainset, self.trainset], axis=0)
                print(f"training client {i} with {len(data1)} samples")
                data1=data1.sample(frac=1).reset_index(drop=True)
                # cập nhật tham số cho client
                if (round>0):
                    self.clients[i].model.load_parameter(self.server_model.get_parameter())
                X_train = data1.iloc[:, 1:].values
                y_train = data1.iloc[:, 0].values
                x_train=torch.tensor((X_train))
                y_train=y_train.squeeze().tolist()
                y_train=torch.tensor(y_train)
                #D_parameters,G_parameters=client.get_parameter()
                results=self.clients[i].model.fit(x_train.float(),y_train,0.003,0.2,15)
                client_params=self.clients[i].model.get_parameter()
                parameter.append(client_params)
            #train server model
            server_params=self.average_parameters(parameter)
            self.server_model.load_parameter(server_params)
            X_server = test_data.iloc[:, 1:].values
            y_server = test_data.iloc[:, 0].values
            x_server=torch.tensor((X_server))
            y_server=y_server.squeeze().tolist()
            y_server=torch.tensor(y_server)

            self.server_model.Cross_validation(x_server,y_server,5,0.003)

            #evaluate round accuracy
            _,accuracy=self.server_model.evaluate(self.testset[0],self.testset[1])
            print(f"round{round} accuracy:{accuracy}")
            _,accuracy_backdoor=self.server_model.evaluate(X_backdoor.float(),Y_backdoor)
            print(f"round{round} accuracy_backdoor:{accuracy_backdoor}")

# %%
fed=server()
# Out:
# 0
# thống kê nhãn subcategory :
# 3 71
# 1 94
# 7 94
# 2 82
# 5 95
# 4 87
# 6 97
# 0 11
# 1
# thống kê nhãn subcategory :
# 7 98
# 1 87
# 6 89
# 2 100
# 5 98
# 4 73
# 3 79
# 0 7
# 2
# thống kê nhãn subcategory :
# 7 95
# 4 84
# 1 99
# 3 88
# 6 86
# 5 83
# 2 82
# 0 14
# 3
# thống kê nhãn subcategory :
# 3 92
# 4 92
# 2 92
# 0 12
# 1 92
# 6 86
# 7 82
# 5 83
# 4
# thống kê nhãn subcategory :
# 1 83
# 2 88
# 4 97
# 5 84
# 3 95
# 6 99
# 7 79
# 0 6
# 5
# thống kê nhãn subcategory :
# 7 98
# 2 97
# 1 78
# 5 96
# 3 76
# 4 86
# 6 90
# 0 10
# 6
# thống kê nhãn subcategory :
# 3 82
# 5 95
# 7 85
# 6 85
# 1 85
# 0 6
# 4 101
# 2 92
# 7
# thống kê nhãn subcategory :
# 6 73
# 7 98
# 5 89
# 3 89
# 1 101
# 2 79
# 4 87
# 0 15

# %%
fed.simulation(6)
# Out:
# training client 0 with 637 samples
# accuracy of epoch 0 is 0.171875, loss : 92.95242309570312
# accuracy of epoch 1 is 0.1328125, loss : 1068.71533203125
# accuracy of epoch 2 is 0.21875, loss : 297.5323486328125
# accuracy of epoch 3 is 0.421875, loss : 54.81727600097656
# accuracy of epoch 4 is 0.4921875, loss : 26.84144401550293
# accuracy of epoch 5 is 0.5390625, loss : 18.260019302368164
# accuracy of epoch 6 is 0.515625, loss : 4.839548110961914
# accuracy of epoch 7 is 0.9140625, loss : 1.1816143989562988
# accuracy of epoch 8 is 0.9453125, loss : 0.5228772759437561
# accuracy of epoch 9 is 0.9609375, loss : 0.35476788878440857
# accuracy of epoch 10 is 0.953125, loss : 0.2541268467903137
# accuracy of epoch 11 is 0.953125, loss : 0.16580668091773987
# accuracy of epoch 12 is 0.9453125, loss : 0.2143329232931137
# accuracy of epoch 13 is 0.96875, loss : 0.1558939814567566
# accuracy of epoch 14 is 0.9375, loss : 0.09046834707260132
# training client 1 with 637 samples
# accuracy of epoch 0 is 0.0078125, loss : 106.15514373779297
# accuracy of epoch 1 is 0.3046875, loss : 255.37339782714844
# accuracy of epoch 2 is 0.125, loss : 498.922607421875
# accuracy of epoch 3 is 0.3828125, loss : 138.92605590820312
# accuracy of epoch 4 is 0.234375, loss : 59.078433990478516
# accuracy of epoch 5 is 0.1640625, loss : 46.45659637451172
# accuracy of epoch 6 is 0.453125, loss : 16.267580032348633
# accuracy of epoch 7 is 0.5234375, loss : 8.051412582397461
# accuracy of epoch 8 is 0.90625, loss : 0.9995129704475403
# accuracy of epoch 9 is 0.96875, loss : 0.4024095833301544
# accuracy of epoch 10 is 0.9609375, loss : 0.2752455174922943
# accuracy of epoch 11 is 0.9765625, loss : 0.18385162949562073
# accuracy of epoch 12 is 0.9296875, loss : 0.20012341439723969
# accuracy of epoch 13 is 0.984375, loss : 0.2815930247306824
# accuracy of epoch 14 is 0.984375, loss : 0.1891579031944275
# training client 2 with 637 samples
# accuracy of epoch 0 is 0.0, loss : 89.09493255615234
# accuracy of epoch 1 is 0.1640625, loss : 247.23431396484375
# accuracy of epoch 2 is 0.1328125, loss : 402.3910217285156
# accuracy of epoch 3 is 0.3828125, loss : 54.83422088623047
# accuracy of epoch 4 is 0.296875, loss : 19.128765106201172
# accuracy of epoch 5 is 0.4921875, loss : 9.22821044921875
# accuracy of epoch 6 is 0.6171875, loss : 3.4676413536071777
# accuracy of epoch 7 is 0.8203125, loss : 1.7330145835876465
# accuracy of epoch 8 is 0.8359375, loss : 0.6168665289878845
# accuracy of epoch 9 is 0.890625, loss : 0.9853252172470093
# accuracy of epoch 10 is 0.9453125, loss : 0.34872323274612427
# accuracy of epoch 11 is 0.9609375, loss : 0.18680575489997864
# accuracy of epoch 12 is 0.96875, loss : 0.1077713817358017
# accuracy of epoch 13 is 0.984375, loss : 0.11384977400302887
# accuracy of epoch 14 is 0.9921875, loss : 0.05081033706665039
# training client 3 with 637 samples
# accuracy of epoch 0 is 0.109375, loss : 120.36387634277344
# accuracy of epoch 1 is 0.1171875, loss : 913.8182983398438
# accuracy of epoch 2 is 0.15625, loss : 153.75363159179688
# accuracy of epoch 3 is 0.2421875, loss : 64.22938537597656
# accuracy of epoch 4 is 0.1953125, loss : 13.838292121887207
# accuracy of epoch 5 is 0.3125, loss : 17.99598503112793
# accuracy of epoch 6 is 0.375, loss : 17.351985931396484
# accuracy of epoch 7 is 0.375, loss : 9.28819465637207
# accuracy of epoch 8 is 0.5078125, loss : 6.815217971801758
# accuracy of epoch 9 is 0.7578125, loss : 1.2134006023406982
# accuracy of epoch 10 is 0.796875, loss : 1.1486146450042725
# accuracy of epoch 11 is 0.7734375, loss : 0.7903398275375366
# accuracy of epoch 12 is 0.8828125, loss : 0.6432321071624756
# accuracy of epoch 13 is 0.90625, loss : 0.1961689591407776
# accuracy of epoch 14 is 0.9453125, loss : 0.13563278317451477
# training client 4 with 637 samples
# accuracy of epoch 0 is 0.1015625, loss : 31.55348014831543
# accuracy of epoch 1 is 0.15625, loss : 1213.1329345703125
# accuracy of epoch 2 is 0.1328125, loss : 401.62786865234375
# accuracy of epoch 3 is 0.1953125, loss : 42.516143798828125
# accuracy of epoch 4 is 0.2578125, loss : 39.86210632324219
# accuracy of epoch 5 is 0.4609375, loss : 11.863171577453613
# accuracy of epoch 6 is 0.6796875, loss : 8.0932035446167
# accuracy of epoch 7 is 0.578125, loss : 7.367127418518066
# accuracy of epoch 8 is 0.515625, loss : 7.789795398712158
# accuracy of epoch 9 is 0.8125, loss : 2.190988540649414
# accuracy of epoch 10 is 0.890625, loss : 1.1217917203903198
# accuracy of epoch 11 is 0.9453125, loss : 0.4488683044910431
# accuracy of epoch 12 is 0.9453125, loss : 0.7706253528594971
# accuracy of epoch 13 is 0.9140625, loss : 0.46965089440345764
# accuracy of epoch 14 is 0.9453125, loss : 0.23636209964752197
# training client 5 with 637 samples
# accuracy of epoch 0 is 0.1640625, loss : 65.18052673339844
# accuracy of epoch 1 is 0.15625, loss : 576.9176635742188
# accuracy of epoch 2 is 0.1640625, loss : 336.67449951171875
# accuracy of epoch 3 is 0.4375, loss : 45.41268539428711
# accuracy of epoch 4 is 0.2265625, loss : 12.509634971618652
# accuracy of epoch 5 is 0.28125, loss : 15.133484840393066
# accuracy of epoch 6 is 0.546875, loss : 7.069560527801514
# accuracy of epoch 7 is 0.34375, loss : 4.629578590393066
# accuracy of epoch 8 is 0.6953125, loss : 3.0697503089904785
# accuracy of epoch 9 is 0.9375, loss : 0.4577893316745758
# accuracy of epoch 10 is 0.9375, loss : 0.29285678267478943
# accuracy of epoch 11 is 0.9609375, loss : 0.33837762475013733
# accuracy of epoch 12 is 0.96875, loss : 0.19716998934745789
# accuracy of epoch 13 is 0.9375, loss : 0.23625141382217407
# accuracy of epoch 14 is 0.9453125, loss : 0.231882706284523
# training client 6 with 637 samples
# accuracy of epoch 0 is 0.21875, loss : 113.69218444824219
# accuracy of epoch 1 is 0.140625, loss : 482.9248962402344
# accuracy of epoch 2 is 0.1953125, loss : 178.1786651611328
# accuracy of epoch 3 is 0.296875, loss : 28.99538803100586
# accuracy of epoch 4 is 0.265625, loss : 47.393985748291016
# accuracy of epoch 5 is 0.328125, loss : 8.66139030456543
# accuracy of epoch 6 is 0.3359375, loss : 10.942544937133789
# accuracy of epoch 7 is 0.3046875, loss : 12.82632827758789
# accuracy of epoch 8 is 0.6171875, loss : 2.261176109313965
# accuracy of epoch 9 is 0.84375, loss : 0.3695962727069855
# accuracy of epoch 10 is 0.8671875, loss : 0.23169688880443573
# accuracy of epoch 11 is 0.921875, loss : 0.14474941790103912
# accuracy of epoch 12 is 0.9375, loss : 0.10054294019937515
# accuracy of epoch 13 is 0.9296875, loss : 0.10406257957220078
# accuracy of epoch 14 is 0.953125, loss : 0.0975610613822937
# training client 7 with 637 samples
# accuracy of epoch 0 is 0.1015625, loss : 107.37313842773438
# accuracy of epoch 1 is 0.15625, loss : 874.7738037109375
# accuracy of epoch 2 is 0.1015625, loss : 160.85140991210938
# accuracy of epoch 3 is 0.2265625, loss : 43.74293518066406
# accuracy of epoch 4 is 0.0546875, loss : 26.022789001464844
# accuracy of epoch 5 is 0.2109375, loss : 13.119577407836914
# accuracy of epoch 6 is 0.4609375, loss : 10.077804565429688
# accuracy of epoch 7 is 0.6640625, loss : 1.9825682640075684
# accuracy of epoch 8 is 0.6171875, loss : 2.46582293510437
# accuracy of epoch 9 is 0.7109375, loss : 4.0330610275268555
# accuracy of epoch 10 is 0.8203125, loss : 0.9886623024940491
# accuracy of epoch 11 is 0.921875, loss : 0.3814769983291626
# accuracy of epoch 12 is 0.9140625, loss : 0.2457962930202484
# accuracy of epoch 13 is 0.9453125, loss : 0.17456717789173126
# accuracy of epoch 14 is 0.9609375, loss : 0.13533350825309753
# length of trainset 1124, length of testset282
# Accuracy for fold 1 : 0.4326241134751773
# length of trainset 1125, length of testset281
# Accuracy for fold 2 : 0.49466192170818507
# length of trainset 1125, length of testset281
# Accuracy for fold 3 : 0.6156583629893239
# length of trainset 1125, length of testset281
# Accuracy for fold 4 : 0.604982206405694
# length of trainset 1125, length of testset281
# Accuracy for fold 5 : 0.6156583629893239
# round0 accuracy:0.6450924608819346
# round0 accuracy_backdoor:0.4802414928649835
# training client 0 with 637 samples
# accuracy of epoch 0 is 0.703125, loss : 0.9117724895477295
# accuracy of epoch 1 is 0.2109375, loss : 80.54364013671875
# accuracy of epoch 2 is 0.2109375, loss : 173.91677856445312
# accuracy of epoch 3 is 0.1796875, loss : 72.81342315673828
# accuracy of epoch 4 is 0.1171875, loss : 37.482418060302734
# accuracy of epoch 5 is 0.2578125, loss : 11.89271068572998
# accuracy of epoch 6 is 0.3125, loss : 7.68625020980835
# accuracy of epoch 7 is 0.546875, loss : 4.204344749450684
# accuracy of epoch 8 is 0.3515625, loss : 3.4570863246917725
# accuracy of epoch 9 is 0.6796875, loss : 1.678698182106018
# accuracy of epoch 10 is 0.59375, loss : 1.6931025981903076
# accuracy of epoch 11 is 0.7109375, loss : 1.1533312797546387
# accuracy of epoch 12 is 0.75, loss : 0.7871460914611816
# accuracy of epoch 13 is 0.7734375, loss : 0.6742315888404846
# accuracy of epoch 14 is 0.8203125, loss : 0.5877501368522644
# training client 1 with 637 samples
# accuracy of epoch 0 is 0.625, loss : 0.856175422668457
# accuracy of epoch 1 is 0.328125, loss : 91.8643569946289
# accuracy of epoch 2 is 0.2734375, loss : 35.36458206176758
# accuracy of epoch 3 is 0.3203125, loss : 22.238555908203125
# accuracy of epoch 4 is 0.203125, loss : 12.821675300598145
# accuracy of epoch 5 is 0.3515625, loss : 1.612019419670105
# accuracy of epoch 6 is 0.4921875, loss : 2.3471617698669434
# accuracy of epoch 7 is 0.4609375, loss : 1.7761788368225098
# accuracy of epoch 8 is 0.5390625, loss : 1.3790810108184814
# accuracy of epoch 9 is 0.5390625, loss : 1.0813971757888794
# accuracy of epoch 10 is 0.5390625, loss : 1.0060012340545654
# accuracy of epoch 11 is 0.5546875, loss : 0.9457089304924011
# accuracy of epoch 12 is 0.5703125, loss : 0.9040400981903076
# accuracy of epoch 13 is 0.578125, loss : 0.8668413162231445
# accuracy of epoch 14 is 0.5703125, loss : 0.8403580188751221
# training client 2 with 637 samples
# accuracy of epoch 0 is 0.5390625, loss : 0.8868998885154724
# accuracy of epoch 1 is 0.125, loss : 104.03273010253906
# accuracy of epoch 2 is 0.15625, loss : 117.51298522949219
# accuracy of epoch 3 is 0.1953125, loss : 75.52153015136719
# accuracy of epoch 4 is 0.328125, loss : 17.802448272705078
# accuracy of epoch 5 is 0.2109375, loss : 21.38716697692871
# accuracy of epoch 6 is 0.328125, loss : 11.010565757751465
# accuracy of epoch 7 is 0.5234375, loss : 7.855912685394287
# accuracy of epoch 8 is 0.390625, loss : 1.897106647491455
# accuracy of epoch 9 is 0.59375, loss : 1.2507107257843018
# accuracy of epoch 10 is 0.4140625, loss : 1.3758949041366577
# accuracy of epoch 11 is 0.390625, loss : 1.4280458688735962
# accuracy of epoch 12 is 0.453125, loss : 1.0871376991271973
# accuracy of epoch 13 is 0.453125, loss : 1.073044776916504
# accuracy of epoch 14 is 0.46875, loss : 1.0322376489639282
# training client 3 with 637 samples
# accuracy of epoch 0 is 0.671875, loss : 0.8509553670883179
# accuracy of epoch 1 is 0.328125, loss : 89.57777404785156
# accuracy of epoch 2 is 0.34375, loss : 183.2760467529297
# accuracy of epoch 3 is 0.171875, loss : 18.699460983276367
# accuracy of epoch 4 is 0.40625, loss : 9.822283744812012
# accuracy of epoch 5 is 0.3984375, loss : 10.482593536376953
# accuracy of epoch 6 is 0.3359375, loss : 5.188502788543701
# accuracy of epoch 7 is 0.359375, loss : 2.544334650039673
# accuracy of epoch 8 is 0.828125, loss : 0.7741990685462952
# accuracy of epoch 9 is 0.828125, loss : 0.5744966268539429
# accuracy of epoch 10 is 0.8984375, loss : 0.4796893000602722
# accuracy of epoch 11 is 0.890625, loss : 0.420771986246109
# accuracy of epoch 12 is 0.8984375, loss : 0.38977739214897156
# accuracy of epoch 13 is 0.9296875, loss : 0.3751891255378723
# accuracy of epoch 14 is 0.890625, loss : 0.38103944063186646
# training client 4 with 637 samples
# accuracy of epoch 0 is 0.6484375, loss : 0.7495317459106445
# accuracy of epoch 1 is 0.171875, loss : 114.01586151123047
# accuracy of epoch 2 is 0.2109375, loss : 11.212363243103027
# accuracy of epoch 3 is 0.265625, loss : 26.831546783447266
# accuracy of epoch 4 is 0.234375, loss : 9.451544761657715
# accuracy of epoch 5 is 0.3515625, loss : 5.556539535522461
# accuracy of epoch 6 is 0.3671875, loss : 2.017174482345581
# accuracy of epoch 7 is 0.578125, loss : 0.932396650314331
# accuracy of epoch 8 is 0.703125, loss : 0.7937799692153931
# accuracy of epoch 9 is 0.65625, loss : 0.6687580347061157
# accuracy of epoch 10 is 0.71875, loss : 0.5468590259552002
# accuracy of epoch 11 is 0.71875, loss : 0.47710636258125305
# accuracy of epoch 12 is 0.71875, loss : 0.41927850246429443
# accuracy of epoch 13 is 0.71875, loss : 0.3903787136077881
# accuracy of epoch 14 is 0.7265625, loss : 0.36590710282325745
# training client 5 with 637 samples
# accuracy of epoch 0 is 0.546875, loss : 0.810241162776947
# accuracy of epoch 1 is 0.2265625, loss : 41.764835357666016
# accuracy of epoch 2 is 0.2109375, loss : 21.43992042541504
# accuracy of epoch 3 is 0.125, loss : 24.42252540588379
# accuracy of epoch 4 is 0.34375, loss : 2.8394625186920166
# accuracy of epoch 5 is 0.3828125, loss : 5.3849196434021
# accuracy of epoch 6 is 0.3203125, loss : 5.365202903747559
# accuracy of epoch 7 is 0.21875, loss : 3.5980639457702637
# accuracy of epoch 8 is 0.3203125, loss : 2.8494772911071777
# accuracy of epoch 9 is 0.5, loss : 1.6466100215911865
# accuracy of epoch 10 is 0.5859375, loss : 1.2240650653839111
# accuracy of epoch 11 is 0.4765625, loss : 1.2141616344451904
# accuracy of epoch 12 is 0.4609375, loss : 1.4158880710601807
# accuracy of epoch 13 is 0.71875, loss : 0.8815690875053406
# accuracy of epoch 14 is 0.609375, loss : 0.9727137088775635
# training client 6 with 637 samples
# accuracy of epoch 0 is 0.703125, loss : 0.8508204817771912
# accuracy of epoch 1 is 0.421875, loss : 51.539031982421875
# accuracy of epoch 2 is 0.1015625, loss : 98.50511932373047
# accuracy of epoch 3 is 0.390625, loss : 17.615379333496094
# accuracy of epoch 4 is 0.25, loss : 4.018996238708496
# accuracy of epoch 5 is 0.2734375, loss : 6.308337688446045
# accuracy of epoch 6 is 0.4140625, loss : 2.422346830368042
# accuracy of epoch 7 is 0.5546875, loss : 2.951172351837158
# accuracy of epoch 8 is 0.71875, loss : 0.8450872302055359
# accuracy of epoch 9 is 0.734375, loss : 0.795663595199585
# accuracy of epoch 10 is 0.75, loss : 0.7664889693260193
# accuracy of epoch 11 is 0.890625, loss : 0.45110875368118286
# accuracy of epoch 12 is 0.8125, loss : 0.40629541873931885
# accuracy of epoch 13 is 0.9453125, loss : 0.3285965621471405
# accuracy of epoch 14 is 0.9609375, loss : 0.2845951020717621
# training client 7 with 637 samples
# accuracy of epoch 0 is 0.6796875, loss : 0.9521618485450745
# accuracy of epoch 1 is 0.5078125, loss : 34.75984191894531
# accuracy of epoch 2 is 0.15625, loss : 36.73891067504883
# accuracy of epoch 3 is 0.140625, loss : 16.986408233642578
# accuracy of epoch 4 is 0.1484375, loss : 10.675817489624023
# accuracy of epoch 5 is 0.1875, loss : 2.539883613586426
# accuracy of epoch 6 is 0.2578125, loss : 2.4923694133758545
# accuracy of epoch 7 is 0.3359375, loss : 3.1574432849884033
# accuracy of epoch 8 is 0.296875, loss : 1.8456594944000244
# accuracy of epoch 9 is 0.375, loss : 1.5821986198425293
# accuracy of epoch 10 is 0.40625, loss : 1.3688840866088867
# accuracy of epoch 11 is 0.53125, loss : 1.3870580196380615
# accuracy of epoch 12 is 0.46875, loss : 1.3418550491333008
# accuracy of epoch 13 is 0.578125, loss : 1.2369968891143799
# accuracy of epoch 14 is 0.75, loss : 1.1464998722076416
# length of trainset 1124, length of testset282
# Accuracy for fold 1 : 0.5390070921985816
# length of trainset 1125, length of testset281
# Accuracy for fold 2 : 0.6441281138790036
# length of trainset 1125, length of testset281
# Accuracy for fold 3 : 0.8362989323843416
# length of trainset 1125, length of testset281
# Accuracy for fold 4 : 0.8576512455516014
# length of trainset 1125, length of testset281
# Accuracy for fold 5 : 0.8647686832740213
# round1 accuracy:0.8890469416785206
# round1 accuracy_backdoor:0.9039517014270033
# training client 0 with 637 samples
# accuracy of epoch 0 is 0.8984375, loss : 0.3246801495552063
# accuracy of epoch 1 is 0.1015625, loss : 217.73410034179688
# accuracy of epoch 2 is 0.078125, loss : 170.40403747558594
# accuracy of epoch 3 is 0.4375, loss : 15.225533485412598
# accuracy of epoch 4 is 0.3671875, loss : 18.49175453186035
# accuracy of epoch 5 is 0.4296875, loss : 5.704763412475586
# accuracy of epoch 6 is 0.2578125, loss : 2.0295519828796387
# accuracy of epoch 7 is 0.4453125, loss : 1.3899818658828735
# accuracy of epoch 8 is 0.421875, loss : 1.2012379169464111
# accuracy of epoch 9 is 0.4375, loss : 1.1357760429382324
# accuracy of epoch 10 is 0.484375, loss : 1.072998285293579
# accuracy of epoch 11 is 0.4765625, loss : 1.016257643699646
# accuracy of epoch 12 is 0.515625, loss : 1.0045170783996582
# accuracy of epoch 13 is 0.4765625, loss : 0.9941158294677734
# accuracy of epoch 14 is 0.4921875, loss : 0.9542846083641052
# training client 1 with 637 samples
# accuracy of epoch 0 is 0.9296875, loss : 0.3608229160308838
# accuracy of epoch 1 is 0.0859375, loss : 128.63075256347656
# accuracy of epoch 2 is 0.3046875, loss : 16.649391174316406
# accuracy of epoch 3 is 0.28125, loss : 2.0219452381134033
# accuracy of epoch 4 is 0.28125, loss : 1.9767366647720337
# accuracy of epoch 5 is 0.1640625, loss : 1.7722787857055664
# accuracy of epoch 6 is 0.2578125, loss : 1.6192072629928589
# accuracy of epoch 7 is 0.234375, loss : 1.538041114807129
# accuracy of epoch 8 is 0.2890625, loss : 1.4841381311416626
# accuracy of epoch 9 is 0.2109375, loss : 1.5407185554504395
# accuracy of epoch 10 is 0.25, loss : 1.6104934215545654
# accuracy of epoch 11 is 0.2890625, loss : 1.5343154668807983
# accuracy of epoch 12 is 0.296875, loss : 1.4607905149459839
# accuracy of epoch 13 is 0.2109375, loss : 1.413859248161316
# accuracy of epoch 14 is 0.234375, loss : 1.388737678527832
# training client 2 with 637 samples
# accuracy of epoch 0 is 0.875, loss : 0.3426235318183899
# accuracy of epoch 1 is 0.2890625, loss : 75.65139770507812
# accuracy of epoch 2 is 0.2890625, loss : 5.7092437744140625
# accuracy of epoch 3 is 0.1796875, loss : 5.6379523277282715
# accuracy of epoch 4 is 0.3125, loss : 5.741703510284424
# accuracy of epoch 5 is 0.2578125, loss : 2.094012975692749
# accuracy of epoch 6 is 0.4296875, loss : 1.4813381433486938
# accuracy of epoch 7 is 0.28125, loss : 12.974303245544434
# accuracy of epoch 8 is 0.2578125, loss : 1.974913477897644
# accuracy of epoch 9 is 0.2578125, loss : 1.8308525085449219
# accuracy of epoch 10 is 0.2578125, loss : 1.7875165939331055
# accuracy of epoch 11 is 0.2578125, loss : 1.771774411201477
# accuracy of epoch 12 is 0.2578125, loss : 1.7638392448425293
# accuracy of epoch 13 is 0.2578125, loss : 1.7592229843139648
# accuracy of epoch 14 is 0.2578125, loss : 1.7552481889724731
# training client 3 with 637 samples
# accuracy of epoch 0 is 0.8984375, loss : 0.2999739646911621
# accuracy of epoch 1 is 0.34375, loss : 120.27598571777344
# accuracy of epoch 2 is 0.2109375, loss : 59.154930114746094
# accuracy of epoch 3 is 0.2109375, loss : 34.596961975097656
# accuracy of epoch 4 is 0.6328125, loss : 6.187821865081787
# accuracy of epoch 5 is 0.625, loss : 1.9662489891052246
# accuracy of epoch 6 is 0.796875, loss : 1.098517894744873
# accuracy of epoch 7 is 0.734375, loss : 0.9134156703948975
# accuracy of epoch 8 is 0.6796875, loss : 0.6391382217407227
# accuracy of epoch 9 is 0.8359375, loss : 0.5550019145011902
# accuracy of epoch 10 is 0.8125, loss : 0.44849830865859985
# accuracy of epoch 11 is 0.828125, loss : 0.422407329082489
# accuracy of epoch 12 is 0.6796875, loss : 0.627307116985321
# accuracy of epoch 13 is 0.8046875, loss : 0.7395241856575012
# accuracy of epoch 14 is 0.8359375, loss : 0.45340755581855774
# training client 4 with 637 samples
# accuracy of epoch 0 is 0.9140625, loss : 0.2703096866607666
# accuracy of epoch 1 is 0.3125, loss : 147.0594940185547
# accuracy of epoch 2 is 0.2734375, loss : 129.775146484375
# accuracy of epoch 3 is 0.265625, loss : 29.15505599975586
# accuracy of epoch 4 is 0.34375, loss : 22.6582088470459
# accuracy of epoch 5 is 0.2890625, loss : 7.711967945098877
# accuracy of epoch 6 is 0.484375, loss : 1.5983082056045532
# accuracy of epoch 7 is 0.484375, loss : 1.396773099899292
# accuracy of epoch 8 is 0.5390625, loss : 1.2983027696609497
# accuracy of epoch 9 is 0.546875, loss : 1.2101240158081055
# accuracy of epoch 10 is 0.5859375, loss : 1.1633931398391724
# accuracy of epoch 11 is 0.59375, loss : 1.1250157356262207
# accuracy of epoch 12 is 0.6171875, loss : 1.0868721008300781
# accuracy of epoch 13 is 0.6484375, loss : 1.0143448114395142
# accuracy of epoch 14 is 0.671875, loss : 0.9785604476928711
# training client 5 with 637 samples
# accuracy of epoch 0 is 0.9296875, loss : 0.3159539997577667
# accuracy of epoch 1 is 0.34375, loss : 90.00617218017578
# accuracy of epoch 2 is 0.296875, loss : 7.9283552169799805
# accuracy of epoch 3 is 0.40625, loss : 6.819022178649902
# accuracy of epoch 4 is 0.2578125, loss : 30.369674682617188
# accuracy of epoch 5 is 0.3125, loss : 3.991147994995117
# accuracy of epoch 6 is 0.2890625, loss : 3.882652521133423
# accuracy of epoch 7 is 0.328125, loss : 1.9440057277679443
# accuracy of epoch 8 is 0.453125, loss : 1.5180249214172363
# accuracy of epoch 9 is 0.453125, loss : 1.4580715894699097
# accuracy of epoch 10 is 0.4609375, loss : 1.2915762662887573
# accuracy of epoch 11 is 0.4609375, loss : 1.2804720401763916
# accuracy of epoch 12 is 0.46875, loss : 1.258648157119751
# accuracy of epoch 13 is 0.4765625, loss : 1.2427984476089478
# accuracy of epoch 14 is 0.4765625, loss : 1.218551516532898
# training client 6 with 637 samples
# accuracy of epoch 0 is 0.90625, loss : 0.28270694613456726
# accuracy of epoch 1 is 0.1796875, loss : 198.24594116210938
# accuracy of epoch 2 is 0.2578125, loss : 82.28336334228516
# accuracy of epoch 3 is 0.3203125, loss : 10.387085914611816
# accuracy of epoch 4 is 0.28125, loss : 8.725142478942871
# accuracy of epoch 5 is 0.3828125, loss : 3.9356164932250977
# accuracy of epoch 6 is 0.3046875, loss : 1.8271921873092651
# accuracy of epoch 7 is 0.328125, loss : 3.7088775634765625
# accuracy of epoch 8 is 0.484375, loss : 1.2243813276290894
# accuracy of epoch 9 is 0.6015625, loss : 1.0144120454788208
# accuracy of epoch 10 is 0.640625, loss : 0.8694133758544922
# accuracy of epoch 11 is 0.734375, loss : 0.9553332924842834
# accuracy of epoch 12 is 0.6640625, loss : 0.72189861536026
# accuracy of epoch 13 is 0.6796875, loss : 0.6782551407814026
# accuracy of epoch 14 is 0.6640625, loss : 0.6364363431930542
# training client 7 with 637 samples
# accuracy of epoch 0 is 0.921875, loss : 0.3056226968765259
# accuracy of epoch 1 is 0.15625, loss : 149.49879455566406
# accuracy of epoch 2 is 0.1875, loss : 63.37308120727539
# accuracy of epoch 3 is 0.1640625, loss : 11.474676132202148
# accuracy of epoch 4 is 0.2734375, loss : 5.139795303344727
# accuracy of epoch 5 is 0.3671875, loss : 3.0658926963806152
# accuracy of epoch 6 is 0.3359375, loss : 1.8423596620559692
# accuracy of epoch 7 is 0.3359375, loss : 1.7034587860107422
# accuracy of epoch 8 is 0.375, loss : 1.6709470748901367
# accuracy of epoch 9 is 0.3828125, loss : 1.6322568655014038
# accuracy of epoch 10 is 0.4296875, loss : 1.592547059059143
# accuracy of epoch 11 is 0.40625, loss : 1.5840387344360352
# accuracy of epoch 12 is 0.4296875, loss : 1.5759766101837158
# accuracy of epoch 13 is 0.4140625, loss : 1.545851707458496
# accuracy of epoch 14 is 0.328125, loss : 1.6051634550094604
# length of trainset 1124, length of testset282
# Accuracy for fold 1 : 0.4787234042553192
# length of trainset 1125, length of testset281
# Accuracy for fold 2 : 0.5409252669039146
# length of trainset 1125, length of testset281
# Accuracy for fold 3 : 0.594306049822064
# length of trainset 1125, length of testset281
# Accuracy for fold 4 : 0.594306049822064
# length of trainset 1125, length of testset281
# Accuracy for fold 5 : 0.6512455516014235
# round2 accuracy:0.6621621621621622
# round2 accuracy_backdoor:0.46871569703622395
# training client 0 with 637 samples
# accuracy of epoch 0 is 0.6484375, loss : 0.9824740886688232
# accuracy of epoch 1 is 0.109375, loss : 188.29664611816406
# accuracy of epoch 2 is 0.34375, loss : 43.929901123046875
# accuracy of epoch 3 is 0.5078125, loss : 3.8798375129699707
# accuracy of epoch 4 is 0.8125, loss : 0.9318782687187195
# accuracy of epoch 5 is 0.8203125, loss : 0.6369048953056335
# accuracy of epoch 6 is 0.875, loss : 0.5192655324935913
# accuracy of epoch 7 is 0.7734375, loss : 0.6111822128295898
# accuracy of epoch 8 is 0.7890625, loss : 0.8928102850914001
# accuracy of epoch 9 is 0.6796875, loss : 0.7870919704437256
# accuracy of epoch 10 is 0.7578125, loss : 0.6526526808738708
# accuracy of epoch 11 is 0.8125, loss : 0.4027048945426941
# accuracy of epoch 12 is 0.8359375, loss : 0.36544960737228394
# accuracy of epoch 13 is 0.859375, loss : 0.34959155321121216
# accuracy of epoch 14 is 0.8828125, loss : 0.33457258343696594
# training client 1 with 637 samples
# accuracy of epoch 0 is 0.6953125, loss : 0.9275888800621033
# accuracy of epoch 1 is 0.109375, loss : 235.554931640625
# accuracy of epoch 2 is 0.46875, loss : 9.266926765441895
# accuracy of epoch 3 is 0.3671875, loss : 4.232446193695068
# accuracy of epoch 4 is 0.3203125, loss : 8.368924140930176
# accuracy of epoch 5 is 0.3828125, loss : 1.4817802906036377
# accuracy of epoch 6 is 0.4296875, loss : 1.4008357524871826
# accuracy of epoch 7 is 0.4453125, loss : 1.3283354043960571
# accuracy of epoch 8 is 0.453125, loss : 1.2920767068862915
# accuracy of epoch 9 is 0.453125, loss : 1.2659162282943726
# accuracy of epoch 10 is 0.453125, loss : 1.247400164604187
# accuracy of epoch 11 is 0.453125, loss : 1.2340837717056274
# accuracy of epoch 12 is 0.453125, loss : 1.2227927446365356
# accuracy of epoch 13 is 0.359375, loss : 1.2137985229492188
# accuracy of epoch 14 is 0.4765625, loss : 1.206167221069336
# training client 2 with 637 samples
# accuracy of epoch 0 is 0.65625, loss : 0.9842240810394287
# accuracy of epoch 1 is 0.140625, loss : 153.6048126220703
# accuracy of epoch 2 is 0.2578125, loss : 20.767004013061523
# accuracy of epoch 3 is 0.3984375, loss : 13.545905113220215
# accuracy of epoch 4 is 0.40625, loss : 1.8243979215621948
# accuracy of epoch 5 is 0.53125, loss : 1.701619029045105
# accuracy of epoch 6 is 0.4609375, loss : 1.3629344701766968
# accuracy of epoch 7 is 0.5078125, loss : 1.250048279762268
# accuracy of epoch 8 is 0.515625, loss : 1.1990262269973755
# accuracy of epoch 9 is 0.5234375, loss : 1.1857980489730835
# accuracy of epoch 10 is 0.515625, loss : 1.1771222352981567
# accuracy of epoch 11 is 0.5234375, loss : 1.1700668334960938
# accuracy of epoch 12 is 0.5234375, loss : 1.1625112295150757
# accuracy of epoch 13 is 0.5234375, loss : 1.1557477712631226
# accuracy of epoch 14 is 0.5234375, loss : 1.1495989561080933
# training client 3 with 637 samples
# accuracy of epoch 0 is 0.6171875, loss : 0.9590067863464355
# accuracy of epoch 1 is 0.2421875, loss : 58.9511833190918
# accuracy of epoch 2 is 0.1875, loss : 10.399450302124023
# accuracy of epoch 3 is 0.4296875, loss : 2.3922014236450195
# accuracy of epoch 4 is 0.3984375, loss : 1.3375996351242065
# accuracy of epoch 5 is 0.4375, loss : 1.0505319833755493
# accuracy of epoch 6 is 0.5390625, loss : 0.9827232360839844
# accuracy of epoch 7 is 0.484375, loss : 0.956407368183136
# accuracy of epoch 8 is 0.5546875, loss : 0.9375780820846558
# accuracy of epoch 9 is 0.4375, loss : 1.3198174238204956
# accuracy of epoch 10 is 0.4453125, loss : 1.5388250350952148
# accuracy of epoch 11 is 0.4453125, loss : 0.9741982221603394
# accuracy of epoch 12 is 0.609375, loss : 0.8937889933586121
# accuracy of epoch 13 is 0.609375, loss : 0.8739072680473328
# accuracy of epoch 14 is 0.609375, loss : 0.8553460240364075
# training client 4 with 637 samples
# accuracy of epoch 0 is 0.6640625, loss : 0.8660022020339966
# accuracy of epoch 1 is 0.125, loss : 152.37681579589844
# accuracy of epoch 2 is 0.265625, loss : 43.251190185546875
# accuracy of epoch 3 is 0.5234375, loss : 3.5130913257598877
# accuracy of epoch 4 is 0.484375, loss : 2.6882376670837402
# accuracy of epoch 5 is 0.578125, loss : 1.746712565422058
# accuracy of epoch 6 is 0.6640625, loss : 1.0115605592727661
# accuracy of epoch 7 is 0.671875, loss : 0.8584324717521667
# accuracy of epoch 8 is 0.671875, loss : 0.7837125062942505
# accuracy of epoch 9 is 0.6875, loss : 0.6989572048187256
# accuracy of epoch 10 is 0.6875, loss : 0.6397032737731934
# accuracy of epoch 11 is 0.6875, loss : 0.5753843188285828
# accuracy of epoch 12 is 0.6796875, loss : 0.526655375957489
# accuracy of epoch 13 is 0.6796875, loss : 0.5237451195716858
# accuracy of epoch 14 is 0.6875, loss : 0.5408148765563965
# training client 5 with 637 samples
# accuracy of epoch 0 is 0.6328125, loss : 0.9510849714279175
# accuracy of epoch 1 is 0.265625, loss : 94.13833618164062
# accuracy of epoch 2 is 0.2109375, loss : 36.944488525390625
# accuracy of epoch 3 is 0.484375, loss : 4.314876079559326
# accuracy of epoch 4 is 0.421875, loss : 1.9412121772766113
# accuracy of epoch 5 is 0.5546875, loss : 1.190725326538086
# accuracy of epoch 6 is 0.4921875, loss : 1.4932395219802856
# accuracy of epoch 7 is 0.4765625, loss : 1.2326425313949585
# accuracy of epoch 8 is 0.484375, loss : 1.2202976942062378
# accuracy of epoch 9 is 0.5078125, loss : 1.2068666219711304
# accuracy of epoch 10 is 0.515625, loss : 1.1809070110321045
# accuracy of epoch 11 is 0.515625, loss : 1.162453293800354
# accuracy of epoch 12 is 0.5703125, loss : 0.9992220997810364
# accuracy of epoch 13 is 0.6015625, loss : 0.9155869483947754
# accuracy of epoch 14 is 0.625, loss : 0.8662054538726807
# training client 6 with 637 samples
# accuracy of epoch 0 is 0.640625, loss : 0.9468294978141785
# accuracy of epoch 1 is 0.1640625, loss : 146.69735717773438
# accuracy of epoch 2 is 0.296875, loss : 50.61233139038086
# accuracy of epoch 3 is 0.375, loss : 7.823256015777588
# accuracy of epoch 4 is 0.5, loss : 5.713316917419434
# accuracy of epoch 5 is 0.5, loss : 1.4486058950424194
# accuracy of epoch 6 is 0.53125, loss : 1.5299571752548218
# accuracy of epoch 7 is 0.703125, loss : 0.9079155921936035
# accuracy of epoch 8 is 0.6796875, loss : 0.760277271270752
# accuracy of epoch 9 is 0.7421875, loss : 0.6413350701332092
# accuracy of epoch 10 is 0.765625, loss : 0.5631039142608643
# accuracy of epoch 11 is 0.765625, loss : 0.5276626348495483
# accuracy of epoch 12 is 0.765625, loss : 0.5161652565002441
# accuracy of epoch 13 is 0.765625, loss : 0.5059813857078552
# accuracy of epoch 14 is 0.734375, loss : 0.564978837966919
# training client 7 with 637 samples
# accuracy of epoch 0 is 0.6875, loss : 1.0159659385681152
# accuracy of epoch 1 is 0.171875, loss : 171.07154846191406
# accuracy of epoch 2 is 0.296875, loss : 5.012171745300293
# accuracy of epoch 3 is 0.5546875, loss : 3.9196691513061523
# accuracy of epoch 4 is 0.421875, loss : 1.4325186014175415
# accuracy of epoch 5 is 0.421875, loss : 1.4238477945327759
# accuracy of epoch 6 is 0.4375, loss : 1.417626976966858
# accuracy of epoch 7 is 0.4453125, loss : 1.4124854803085327
# accuracy of epoch 8 is 0.4453125, loss : 1.4061087369918823
# accuracy of epoch 9 is 0.4375, loss : 1.4002025127410889
# accuracy of epoch 10 is 0.453125, loss : 1.3955248594284058
# accuracy of epoch 11 is 0.453125, loss : 1.391753077507019
# accuracy of epoch 12 is 0.453125, loss : 1.3885829448699951
# accuracy of epoch 13 is 0.453125, loss : 1.385613203048706
# accuracy of epoch 14 is 0.453125, loss : 1.3824284076690674
# length of trainset 1124, length of testset282
# Accuracy for fold 1 : 0.7836879432624113
# length of trainset 1125, length of testset281
# Accuracy for fold 2 : 0.7829181494661922
# length of trainset 1125, length of testset281
# Accuracy for fold 3 : 0.7900355871886121
# length of trainset 1125, length of testset281
# Accuracy for fold 4 : 0.8078291814946619
# length of trainset 1125, length of testset281
# Accuracy for fold 5 : 0.8362989323843416
# round3 accuracy:0.8378378378378378
# round3 accuracy_backdoor:0.7277716794731065
# training client 0 with 637 samples
# accuracy of epoch 0 is 0.828125, loss : 0.3448816239833832
# accuracy of epoch 1 is 0.2734375, loss : 27.702333450317383
# accuracy of epoch 2 is 0.1953125, loss : 4.603823184967041
# accuracy of epoch 3 is 0.375, loss : 9.007651329040527
# accuracy of epoch 4 is 0.2265625, loss : 15.898926734924316
# accuracy of epoch 5 is 0.3125, loss : 2.4722037315368652
# accuracy of epoch 6 is 0.34375, loss : 1.6581538915634155
# accuracy of epoch 7 is 0.3046875, loss : 1.5930380821228027
# accuracy of epoch 8 is 0.3046875, loss : 1.5553613901138306
# accuracy of epoch 9 is 0.3125, loss : 1.5136405229568481
# accuracy of epoch 10 is 0.3203125, loss : 1.5004957914352417
# accuracy of epoch 11 is 0.3359375, loss : 1.4772930145263672
# accuracy of epoch 12 is 0.34375, loss : 1.4470875263214111
# accuracy of epoch 13 is 0.40625, loss : 1.3846514225006104
# accuracy of epoch 14 is 0.375, loss : 1.6488966941833496
# training client 1 with 637 samples
# accuracy of epoch 0 is 0.8125, loss : 0.3841199576854706
# accuracy of epoch 1 is 0.1796875, loss : 33.18225860595703
# accuracy of epoch 2 is 0.53125, loss : 5.164609432220459
# accuracy of epoch 3 is 0.3125, loss : 3.4371912479400635
# accuracy of epoch 4 is 0.3359375, loss : 3.6527891159057617
# accuracy of epoch 5 is 0.28125, loss : 3.1818666458129883
# accuracy of epoch 6 is 0.59375, loss : 1.0244901180267334
# accuracy of epoch 7 is 0.6484375, loss : 0.6983593702316284
# accuracy of epoch 8 is 0.5234375, loss : 1.4291259050369263
# accuracy of epoch 9 is 0.6171875, loss : 1.0799347162246704
# accuracy of epoch 10 is 0.71875, loss : 0.9845775961875916
# accuracy of epoch 11 is 0.703125, loss : 0.7251173257827759
# accuracy of epoch 12 is 0.734375, loss : 0.6659494638442993
# accuracy of epoch 13 is 0.7890625, loss : 0.4430707097053528
# accuracy of epoch 14 is 0.8046875, loss : 0.39017531275749207
# training client 2 with 637 samples
# accuracy of epoch 0 is 0.8125, loss : 0.5228212475776672
# accuracy of epoch 1 is 0.15625, loss : 36.55716323852539
# accuracy of epoch 2 is 0.0234375, loss : 35.08122253417969
# accuracy of epoch 3 is 0.21875, loss : 78.70112609863281
# accuracy of epoch 4 is 0.390625, loss : 5.970669746398926
# accuracy of epoch 5 is 0.515625, loss : 5.476200103759766
# accuracy of epoch 6 is 0.484375, loss : 3.8338303565979004
# accuracy of epoch 7 is 0.59375, loss : 2.05641508102417
# accuracy of epoch 8 is 0.5078125, loss : 1.4701650142669678
# accuracy of epoch 9 is 0.7265625, loss : 1.0729867219924927
# accuracy of epoch 10 is 0.578125, loss : 0.7620311975479126
# accuracy of epoch 11 is 0.7109375, loss : 0.6150144934654236
# accuracy of epoch 12 is 0.703125, loss : 0.5976663827896118
# accuracy of epoch 13 is 0.703125, loss : 0.5861049294471741
# accuracy of epoch 14 is 0.703125, loss : 0.5775398015975952
# training client 3 with 637 samples
# accuracy of epoch 0 is 0.8203125, loss : 0.3148210048675537
# accuracy of epoch 1 is 0.234375, loss : 96.44969940185547
# accuracy of epoch 2 is 0.234375, loss : 39.52170181274414
# accuracy of epoch 3 is 0.328125, loss : 11.430046081542969
# accuracy of epoch 4 is 0.296875, loss : 8.758233070373535
# accuracy of epoch 5 is 0.578125, loss : 1.4607326984405518
# accuracy of epoch 6 is 0.640625, loss : 0.6946286559104919
# accuracy of epoch 7 is 0.6953125, loss : 0.5681267380714417
# accuracy of epoch 8 is 0.7578125, loss : 0.5234476923942566
# accuracy of epoch 9 is 0.7890625, loss : 0.44490569829940796
# accuracy of epoch 10 is 0.796875, loss : 0.4227936267852783
# accuracy of epoch 11 is 0.7265625, loss : 0.8561674356460571
# accuracy of epoch 12 is 0.765625, loss : 0.4695751667022705
# accuracy of epoch 13 is 0.75, loss : 0.39080265164375305
# accuracy of epoch 14 is 0.7890625, loss : 0.340583860874176
# training client 4 with 637 samples
# accuracy of epoch 0 is 0.8046875, loss : 0.2505689561367035
# accuracy of epoch 1 is 0.375, loss : 14.415520668029785
# accuracy of epoch 2 is 0.1484375, loss : 42.435306549072266
# accuracy of epoch 3 is 0.5390625, loss : 10.978400230407715
# accuracy of epoch 4 is 0.7109375, loss : 1.505050778388977
# accuracy of epoch 5 is 0.6484375, loss : 1.0641237497329712
# accuracy of epoch 6 is 0.46875, loss : 1.3042316436767578
# accuracy of epoch 7 is 0.53125, loss : 1.1054435968399048
# accuracy of epoch 8 is 0.609375, loss : 1.5322041511535645
# accuracy of epoch 9 is 0.5078125, loss : 1.133791208267212
# accuracy of epoch 10 is 0.515625, loss : 1.034532070159912
# accuracy of epoch 11 is 0.5234375, loss : 1.0262515544891357
# accuracy of epoch 12 is 0.5234375, loss : 1.018916130065918
# accuracy of epoch 13 is 0.5234375, loss : 1.0152499675750732
# accuracy of epoch 14 is 0.5234375, loss : 1.0123002529144287
# training client 5 with 637 samples
# accuracy of epoch 0 is 0.8203125, loss : 0.3223258852958679
# accuracy of epoch 1 is 0.1484375, loss : 75.77568817138672
# accuracy of epoch 2 is 0.4921875, loss : 2.496875762939453
# accuracy of epoch 3 is 0.203125, loss : 9.621240615844727
# accuracy of epoch 4 is 0.453125, loss : 1.8879557847976685
# accuracy of epoch 5 is 0.46875, loss : 1.1786112785339355
# accuracy of epoch 6 is 0.3828125, loss : 5.848179817199707
# accuracy of epoch 7 is 0.6640625, loss : 1.046886920928955
# accuracy of epoch 8 is 0.7890625, loss : 0.8722708821296692
# accuracy of epoch 9 is 0.84375, loss : 0.8172909617424011
# accuracy of epoch 10 is 0.8046875, loss : 0.738089382648468
# accuracy of epoch 11 is 0.7890625, loss : 0.6769632697105408
# accuracy of epoch 12 is 0.8125, loss : 0.6596217155456543
# accuracy of epoch 13 is 0.703125, loss : 0.9422663450241089
# accuracy of epoch 14 is 0.765625, loss : 0.8359680771827698
# training client 6 with 637 samples
# accuracy of epoch 0 is 0.875, loss : 0.28853839635849
# accuracy of epoch 1 is 0.265625, loss : 95.7396240234375
# accuracy of epoch 2 is 0.1875, loss : 96.24679565429688
# accuracy of epoch 3 is 0.3359375, loss : 5.157320976257324
# accuracy of epoch 4 is 0.7578125, loss : 0.7573937177658081
# accuracy of epoch 5 is 0.828125, loss : 0.45350342988967896
# accuracy of epoch 6 is 0.8984375, loss : 0.32330322265625
# accuracy of epoch 7 is 0.921875, loss : 0.24747836589813232
# accuracy of epoch 8 is 0.9296875, loss : 0.2008168250322342
# accuracy of epoch 9 is 0.875, loss : 0.17559969425201416
# accuracy of epoch 10 is 0.8359375, loss : 0.34924107789993286
# accuracy of epoch 11 is 0.84375, loss : 0.5626871585845947
# accuracy of epoch 12 is 0.8359375, loss : 0.3348875343799591
# accuracy of epoch 13 is 0.8984375, loss : 0.2737070620059967
# accuracy of epoch 14 is 0.921875, loss : 0.2147945612668991
# training client 7 with 637 samples
# accuracy of epoch 0 is 0.796875, loss : 0.36091452836990356
# accuracy of epoch 1 is 0.234375, loss : 22.434856414794922
# accuracy of epoch 2 is 0.3203125, loss : 24.305519104003906
# accuracy of epoch 3 is 0.171875, loss : 6.245687484741211
# accuracy of epoch 4 is 0.3046875, loss : 2.72123122215271
# accuracy of epoch 5 is 0.328125, loss : 1.8273855447769165
# accuracy of epoch 6 is 0.3828125, loss : 1.8042230606079102
# accuracy of epoch 7 is 0.3203125, loss : 1.4346433877944946
# accuracy of epoch 8 is 0.3828125, loss : 1.3807157278060913
# accuracy of epoch 9 is 0.3828125, loss : 1.3659095764160156
# accuracy of epoch 10 is 0.3828125, loss : 1.3643662929534912
# accuracy of epoch 11 is 0.3828125, loss : 1.3563114404678345
# accuracy of epoch 12 is 0.390625, loss : 1.3536046743392944
# accuracy of epoch 13 is 0.3828125, loss : 1.3613190650939941
# accuracy of epoch 14 is 0.3828125, loss : 1.3602334260940552
# length of trainset 1124, length of testset282
# Accuracy for fold 1 : 0.425531914893617
# length of trainset 1125, length of testset281
# Accuracy for fold 2 : 0.5302491103202847
# length of trainset 1125, length of testset281
# Accuracy for fold 3 : 0.6014234875444839
# length of trainset 1125, length of testset281
# Accuracy for fold 4 : 0.5871886120996441
# length of trainset 1125, length of testset281
# Accuracy for fold 5 : 0.5444839857651246
# round4 accuracy:0.5633001422475107
# round4 accuracy_backdoor:0.9193194291986828
# training client 0 with 637 samples
# accuracy of epoch 0 is 0.5625, loss : 1.0139111280441284
# accuracy of epoch 1 is 0.21875, loss : 342.1910705566406
# accuracy of epoch 2 is 0.3046875, loss : 12.847023010253906
# accuracy of epoch 3 is 0.328125, loss : 3.526122570037842
# accuracy of epoch 4 is 0.484375, loss : 1.2255465984344482
# accuracy of epoch 5 is 0.4765625, loss : 1.244337797164917
# accuracy of epoch 6 is 0.625, loss : 1.1112403869628906
# accuracy of epoch 7 is 0.65625, loss : 0.9526132941246033
# accuracy of epoch 8 is 0.75, loss : 1.0358282327651978
# accuracy of epoch 9 is 0.546875, loss : 0.9949345588684082
# accuracy of epoch 10 is 0.6640625, loss : 0.8702285885810852
# accuracy of epoch 11 is 0.5859375, loss : 0.8297128081321716
# accuracy of epoch 12 is 0.5546875, loss : 0.8534330129623413
# accuracy of epoch 13 is 0.59375, loss : 0.9228864908218384
# accuracy of epoch 14 is 0.6015625, loss : 0.8796001672744751
# training client 1 with 637 samples
# accuracy of epoch 0 is 0.53125, loss : 1.0333402156829834
# accuracy of epoch 1 is 0.34375, loss : 36.04669952392578
# accuracy of epoch 2 is 0.1640625, loss : 28.679241180419922
# accuracy of epoch 3 is 0.53125, loss : 3.0501155853271484
# accuracy of epoch 4 is 0.34375, loss : 3.161090135574341
# accuracy of epoch 5 is 0.390625, loss : 2.2808334827423096
# accuracy of epoch 6 is 0.4296875, loss : 9.836385726928711
# accuracy of epoch 7 is 0.3671875, loss : 3.709735631942749
# accuracy of epoch 8 is 0.3046875, loss : 1.7669620513916016
# accuracy of epoch 9 is 0.3125, loss : 1.5980308055877686
# accuracy of epoch 10 is 0.3125, loss : 1.5470671653747559
# accuracy of epoch 11 is 0.328125, loss : 1.5184398889541626
# accuracy of epoch 12 is 0.4609375, loss : 1.4837013483047485
# accuracy of epoch 13 is 0.484375, loss : 1.439475655555725
# accuracy of epoch 14 is 0.4921875, loss : 1.3859977722167969
# training client 2 with 637 samples
# accuracy of epoch 0 is 0.5625, loss : 1.0682296752929688
# accuracy of epoch 1 is 0.1796875, loss : 140.19984436035156
# accuracy of epoch 2 is 0.1484375, loss : 5.788650989532471
# accuracy of epoch 3 is 0.1796875, loss : 2.0486385822296143
# accuracy of epoch 4 is 0.28125, loss : 1.6281845569610596
# accuracy of epoch 5 is 0.3046875, loss : 1.5709649324417114
# accuracy of epoch 6 is 0.3125, loss : 1.5049805641174316
# accuracy of epoch 7 is 0.296875, loss : 1.4430655241012573
# accuracy of epoch 8 is 0.3828125, loss : 1.468529462814331
# accuracy of epoch 9 is 0.40625, loss : 1.4208087921142578
# accuracy of epoch 10 is 0.453125, loss : 1.3245899677276611
# accuracy of epoch 11 is 0.5078125, loss : 1.2853456735610962
# accuracy of epoch 12 is 0.5078125, loss : 1.2677279710769653
# accuracy of epoch 13 is 0.5, loss : 1.2522437572479248
# accuracy of epoch 14 is 0.5078125, loss : 1.2368910312652588
# training client 3 with 637 samples
# accuracy of epoch 0 is 0.609375, loss : 1.0752036571502686
# accuracy of epoch 1 is 0.265625, loss : 201.7041473388672
# accuracy of epoch 2 is 0.40625, loss : 12.71072006225586
# accuracy of epoch 3 is 0.5703125, loss : 3.8455841541290283
# accuracy of epoch 4 is 0.5546875, loss : 2.2835066318511963
# accuracy of epoch 5 is 0.6171875, loss : 1.604920506477356
# accuracy of epoch 6 is 0.65625, loss : 0.9452619552612305
# accuracy of epoch 7 is 0.5703125, loss : 0.8791786432266235
# accuracy of epoch 8 is 0.78125, loss : 0.8535031676292419
# accuracy of epoch 9 is 0.6015625, loss : 0.8090648651123047
# accuracy of epoch 10 is 0.75, loss : 0.8079158067703247
# accuracy of epoch 11 is 0.6484375, loss : 0.7727975845336914
# accuracy of epoch 12 is 0.7109375, loss : 0.7667450308799744
# accuracy of epoch 13 is 0.6171875, loss : 0.7677855491638184
# accuracy of epoch 14 is 0.7734375, loss : 0.7659392356872559
# training client 4 with 637 samples
# accuracy of epoch 0 is 0.5625, loss : 0.9721793532371521
# accuracy of epoch 1 is 0.1328125, loss : 239.36288452148438
# accuracy of epoch 2 is 0.3125, loss : 1.9563045501708984
# accuracy of epoch 3 is 0.3203125, loss : 1.4541999101638794
# accuracy of epoch 4 is 0.34375, loss : 1.3568060398101807
# accuracy of epoch 5 is 0.359375, loss : 1.3339884281158447
# accuracy of epoch 6 is 0.359375, loss : 1.3191529512405396
# accuracy of epoch 7 is 0.265625, loss : 2.0054376125335693
# accuracy of epoch 8 is 0.34375, loss : 1.3783385753631592
# accuracy of epoch 9 is 0.34375, loss : 1.3566315174102783
# accuracy of epoch 10 is 0.34375, loss : 1.3435994386672974
# accuracy of epoch 11 is 0.34375, loss : 1.3299999237060547
# accuracy of epoch 12 is 0.3515625, loss : 1.3217482566833496
# accuracy of epoch 13 is 0.3515625, loss : 1.3187315464019775
# accuracy of epoch 14 is 0.3515625, loss : 1.311812162399292
# training client 5 with 637 samples
# accuracy of epoch 0 is 0.59375, loss : 1.0620908737182617
# accuracy of epoch 1 is 0.296875, loss : 14.524820327758789
# accuracy of epoch 2 is 0.2890625, loss : 14.129013061523438
# accuracy of epoch 3 is 0.2734375, loss : 6.107050895690918
# accuracy of epoch 4 is 0.3125, loss : 1.7743053436279297
# accuracy of epoch 5 is 0.265625, loss : 1.7375444173812866
# accuracy of epoch 6 is 0.2734375, loss : 1.707991600036621
# accuracy of epoch 7 is 0.265625, loss : 1.7000783681869507
# accuracy of epoch 8 is 0.265625, loss : 1.6918007135391235
# accuracy of epoch 9 is 0.265625, loss : 1.6854828596115112
# accuracy of epoch 10 is 0.265625, loss : 1.6813690662384033
# accuracy of epoch 11 is 0.265625, loss : 1.6816376447677612
# accuracy of epoch 12 is 0.265625, loss : 1.7002335786819458
# accuracy of epoch 13 is 0.265625, loss : 1.6929553747177124
# accuracy of epoch 14 is 0.265625, loss : 1.672217845916748
# training client 6 with 637 samples
# accuracy of epoch 0 is 0.5703125, loss : 1.0345584154129028
# accuracy of epoch 1 is 0.34375, loss : 3.6448817253112793
# accuracy of epoch 2 is 0.4921875, loss : 8.791426658630371
# accuracy of epoch 3 is 0.265625, loss : 1.816107153892517
# accuracy of epoch 4 is 0.2890625, loss : 1.7012979984283447
# accuracy of epoch 5 is 0.2890625, loss : 1.6905004978179932
# accuracy of epoch 6 is 0.2890625, loss : 1.6806108951568604
# accuracy of epoch 7 is 0.3046875, loss : 21.561031341552734
# accuracy of epoch 8 is 0.296875, loss : 1.6893715858459473
# accuracy of epoch 9 is 0.3515625, loss : 1.6178196668624878
# accuracy of epoch 10 is 0.4453125, loss : 3.7214722633361816
# accuracy of epoch 11 is 0.4609375, loss : 2.04145884513855
# accuracy of epoch 12 is 0.34375, loss : 1.5575242042541504
# accuracy of epoch 13 is 0.359375, loss : 1.5178072452545166
# accuracy of epoch 14 is 0.3828125, loss : 1.4739741086959839
# training client 7 with 637 samples
# accuracy of epoch 0 is 0.6015625, loss : 1.0747015476226807
# accuracy of epoch 1 is 0.25, loss : 118.96894836425781
# accuracy of epoch 2 is 0.3984375, loss : 2.8038411140441895
# accuracy of epoch 3 is 0.3828125, loss : 2.080535888671875
# accuracy of epoch 4 is 0.46875, loss : 1.53903329372406
# accuracy of epoch 5 is 0.4140625, loss : 1.681497573852539
# accuracy of epoch 6 is 0.5, loss : 1.5225465297698975
# accuracy of epoch 7 is 0.46875, loss : 1.4343044757843018
# accuracy of epoch 8 is 0.5859375, loss : 1.2746316194534302
# accuracy of epoch 9 is 0.4296875, loss : 3.5083701610565186
# accuracy of epoch 10 is 0.390625, loss : 5.708010673522949
# accuracy of epoch 11 is 0.5, loss : 1.3885858058929443
# accuracy of epoch 12 is 0.5234375, loss : 1.3679474592208862
# accuracy of epoch 13 is 0.5234375, loss : 1.3538424968719482
# accuracy of epoch 14 is 0.5234375, loss : 1.3400020599365234
# length of trainset 1124, length of testset282
# Accuracy for fold 1 : 0.43617021276595747
# length of trainset 1125, length of testset281
# Accuracy for fold 2 : 0.5124555160142349
# length of trainset 1125, length of testset281
# Accuracy for fold 3 : 0.7330960854092526
# length of trainset 1125, length of testset281
# Accuracy for fold 4 : 0.7224199288256228
# length of trainset 1125, length of testset281
# Accuracy for fold 5 : 0.7686832740213523
# round5 accuracy:0.7795163584637269
# round5 accuracy_backdoor:0.8600439077936334

# %% [markdown]
# #Train models with IID and non-IID data
