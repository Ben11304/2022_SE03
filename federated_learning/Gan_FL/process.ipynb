# %%
import pandas as pd
data=pd.read_csv("/Users/mac/Dev/2022_SE03/data/raw_20k_data.csv")
# Out:
# /var/folders/0j/2h4f0bj12r775fg_s2v4hpqh0000gn/T/ipykernel_7383/3013472152.py:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("/Users/mac/Dev/2022_SE03/data/raw_20k_data.csv")

# %%
# df là DataFrame của bạn
data = data.dropna(axis=1, how='all')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260607 entries, 0 to 260606
# Data columns (total 29 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   pkSeqID       260607 non-null  int64
#  1   stime         260607 non-null  float64
#  2   flgs          260607 non-null  object
#  3   proto         260607 non-null  object
#  4   saddr         260607 non-null  object
#  5   sport         260005 non-null  object
#  6   daddr         260607 non-null  object
#  7   dport         260005 non-null  object
#  8   pkts          260607 non-null  int64
#  9   bytes         260607 non-null  int64
#  10  state         260607 non-null  object
#  11  ltime         260607 non-null  float64
#  12  seq           260607 non-null  int64
#  13  dur           260607 non-null  float64
#  14  mean          260607 non-null  float64
#  15  stddev        260607 non-null  float64
#  16  sum           260607 non-null  float64
# ...

# %%
from data_work import processed
last=processed(data,"subcategory ")

# %%
last
# Out:
#         subcategory   pkSeqID   stime  flgs  proto  saddr  sport  daddr  \
# 0                  7   188809  130743     0      6      5  12626     37
# 1                  6   243306  194056    10      5      8  47412     34
# 2                  7   143289   99255     0      6      5  51883     37
# 3                  4    85020   74004     0      5      5  56325     40
# 4                  1   130584  153341     0      5     10  58481     28
# ...              ...      ...     ...   ...    ...    ...    ...    ...
# 260602             6   256290  206910    10      5      8  58871     34
# 260603             5    22173   20523     0      5      5  41366     34
# 260604             7   147386  102715    11      6      7  21276     39
# 260605             6   254103  204723    10      5      8  58341     34
# 260606             5      360     362     0      5      8  23509     34
#
#         dport  pkts  ...    max  spkts  dpkts  sbytes  dbytes   rate  srate  \
# ...

# %%
last.to_csv("/Users/mac/Dev/2022_SE03/data/processed_20k.csv",index=False)
