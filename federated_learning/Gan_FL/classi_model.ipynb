# %%
from model import Net
import torch
import pandas as pd

# %%
import pandas as pd
data=pd.read_csv("/Users/mac/Dev/source/article/FerderatedLearning/federated_learning/Federated_with_GAN/data_fine/lasted_data.csv",index_col=None)

# %%
from sklearn.model_selection import train_test_split
data,test_data=train_test_split(data,test_size=0.8
                                ,random_state=42)
data=data.drop("Unnamed: 0",axis=1)

# %%
data
# Out:
#       subcategory   pkSeqID  stime  flgs  proto  saddr  sport  daddr  dport  \
# 6346             6     5614   3123     7      2      1   1638     22    901
# 3190             7     6223   3724     0      3      0    512     25    901
# 4566             7     6992   4371     0      3      0   2242     25    901
# 4802             7     6940   4347     0      3      0   2175     25    901
# 6583             6     6017   3526     7      2      1   1871     22    901
# ...            ...      ...    ...   ...    ...    ...    ...    ...    ...
# 3772             1     4220   4586     0      2      3   3443     20    900
# 5191             2     3284   5857     0      2      5   4245     17    600
# 5226             7     6847   4280     0      3      0   2048     25    901
# 5390             7     6248   3745     0      3      0    538     25    901
# 860              7     6899   4319     0      3      0   2122     25    901
#
#       pkts  ...   max  spkts  dpkts  sbytes  dbytes  rate  srate  drate  \
# 6346     2  ...     0      2      0      63       0    28     23      0
# 3190     9  ...  2031      9      0      71       0   377    561      0
# 4566     9  ...  2110      9      0      71       0   355    539      0
# 4802     9  ...  2054      9      0      71       0   360    544      0
# 6583     3  ...  1042      2      1      63       1    93     21      0
# ...    ...  ...   ...    ...    ...     ...     ...   ...    ...    ...
# 3772     7  ...  1493      4      3     230      78  1110   1015    698
# 5191     1  ...   229      0      1       2       1  2238      0      0
# 5226     9  ...  2132      9      0      71       0   370    554      0
# 5390     9  ...  2033      9      0      71       0   378    562      0
# 860      9  ...  2152      9      0      71       0   365    549      0
#
#       attack  category
# 6346       1         0
# 3190       1         0
# 4566       1         0
# 4802       1         0
# 6583       1         0
# ...      ...       ...
# 3772       1         0
# 5191       1         3
# 5226       1         0
# 5390       1         0
# 860        1         0
#
# [1405 rows x 29 columns]

# %%
tensor=torch.tensor(data.values)
X=tensor[:,1:]
X=X.float()
y=tensor[:,:1]
y=y.squeeze().tolist()
y=torch.tensor(y)
model= Net(0.00)
model.fit(X,y,0.003,0.2,20)
# Out:
# accuracy of epoch 0 is 0.18861209964412812, loss : 53.15470504760742
# accuracy of epoch 1 is 0.3167259786476868, loss : 872.5030517578125
# accuracy of epoch 2 is 0.2206405693950178, loss : 263.0679626464844
# accuracy of epoch 3 is 0.3879003558718861, loss : 47.34679412841797
# accuracy of epoch 4 is 0.2313167259786477, loss : 20.275381088256836
# accuracy of epoch 5 is 0.4804270462633452, loss : 10.182153701782227
# accuracy of epoch 6 is 0.6690391459074733, loss : 3.0731961727142334
# accuracy of epoch 7 is 0.7651245551601423, loss : 1.461295485496521
# accuracy of epoch 8 is 0.9181494661921709, loss : 0.38538479804992676
# accuracy of epoch 9 is 0.9608540925266904, loss : 0.18798671662807465
# accuracy of epoch 10 is 0.9644128113879004, loss : 0.12007814645767212
# accuracy of epoch 11 is 0.9715302491103203, loss : 0.08371862024068832
# accuracy of epoch 12 is 0.9750889679715302, loss : 0.06859568506479263
# accuracy of epoch 13 is 0.9715302491103203, loss : 0.05470503494143486
# accuracy of epoch 14 is 0.9715302491103203, loss : 0.0456908717751503
# accuracy of epoch 15 is 0.9786476868327402, loss : 0.03867219388484955
# accuracy of epoch 16 is 0.9786476868327402, loss : 0.034182365983724594
# accuracy of epoch 17 is 0.9786476868327402, loss : 0.030963167548179626
# accuracy of epoch 18 is 0.9822064056939501, loss : 0.028174912557005882
# accuracy of epoch 19 is 0.9822064056939501, loss : 0.02670217491686344
# {'loss': [53.15470504760742,
#   872.5030517578125,
#   263.0679626464844,
#   47.34679412841797,
#   20.275381088256836,
#   10.182153701782227,
#   3.0731961727142334,
#   1.461295485496521,
#   0.38538479804992676,
#   0.18798671662807465,
#   0.12007814645767212,
#   0.08371862024068832,
#   0.06859568506479263,
#   0.05470503494143486,
#   0.0456908717751503,
#   0.03867219388484955,
#   0.034182365983724594,
#   0.030963167548179626,
#   0.028174912557005882,
#   0.02670217491686344],
#  'accuracy': [0.18416370106761565,
#   0.28647686832740216,
#   0.22953736654804271,
#   0.4128113879003559,
#   0.20551601423487545,
#   0.5204626334519573,
#   0.6628113879003559,
#   0.7775800711743772,
#   0.9350533807829181,
#   0.9617437722419929,
#   0.9715302491103203,
#   0.9822064056939501,
#   0.9839857651245552,
#   0.9875444839857651,
#   0.9884341637010676,
#   0.9893238434163701,
#   0.9919928825622776,
#   0.9919928825622776,
#   0.9919928825622776,
#   0.9937722419928826],
#  'val_loss': [54.263458251953125,
#   878.3753662109375,
#   264.051025390625,
#   48.682518005371094,
#   20.817001342773438,
#   11.41353988647461,
#   3.0053398609161377,
#   1.7431341409683228,
#   0.5517594814300537,
#   0.28699877858161926,
#   0.2164548933506012,
#   0.18480053544044495,
#   0.1472265124320984,
#   0.13866959512233734,
#   0.1333121508359909,
#   0.12830570340156555,
#   0.1231195479631424,
#   0.12137681245803833,
#   0.11429229378700256,
#   0.11194995790719986],
#  'val_accuracy': [0.18861209964412812,
#   0.3167259786476868,
#   0.2206405693950178,
#   0.3879003558718861,
#   0.2313167259786477,
#   0.4804270462633452,
#   0.6690391459074733,
#   0.7651245551601423,
#   0.9181494661921709,
#   0.9608540925266904,
#   0.9644128113879004,
#   0.9715302491103203,
#   0.9750889679715302,
#   0.9715302491103203,
#   0.9715302491103203,
#   0.9786476868327402,
#   0.9786476868327402,
#   0.9786476868327402,
#   0.9822064056939501,
#   0.9822064056939501]}
